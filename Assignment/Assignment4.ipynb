# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Dataset_Day4.csv')
data.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17    30.00     63.15  48.89
# 3       7       81.22     96.06    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Prefix      99 non-null     int64
#  1   Assignment  99 non-null     float64
#  2   Tutorial    99 non-null     float64
#  3   Midterm     99 non-null     float64
#  4   TakeHome    98 non-null     float64
#  5   Final       96 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 4.8 KB

# %%
# 1.	Find and treat all the missing values. Rows or columns with missing values must not be dropped.
data.isna().sum()/len(data)*100
# Out:
# Prefix        0.000000
# Assignment    0.000000
# Tutorial      0.000000
# Midterm       0.000000
# TakeHome      1.010101
# Final         3.030303
# dtype: float64

# %%
data.skew()
# Out:
# Prefix       -1.746493
# Assignment   -1.676609
# Tutorial     -1.472330
# Midterm      -0.063458
# TakeHome     -1.175746
# Final         0.096656
# dtype: float64

# %%
data['TakeHome'].fillna(data['TakeHome'].median(),inplace=True)
data['Final'].fillna(data['Final'].mean(),inplace=True)
data.isna().sum()/len(data)*100
# Out:
# Prefix        0.0
# Assignment    0.0
# Tutorial      0.0
# Midterm       0.0
# TakeHome      0.0
# Final         0.0
# dtype: float64

# %%
# 2.	Make an in-depth report on the variables using descriptive statistics and also portray the relationship between each variables using visualizations.

df = data.describe()
print(df)
# Out:
#           Prefix  Assignment    Tutorial     Midterm    TakeHome       Final
# count  99.000000   99.000000   99.000000   99.000000   99.000000   99.000000
# mean    7.313131   85.491717   89.731111   68.049495   80.900505   68.414375
# std     0.932918   12.597694   15.071556   19.376074   23.697863   18.511079
# min     4.000000   28.140000   34.090000   28.120000   16.910000   28.060000
# 25%     7.000000   80.875000   83.350000   52.810000   67.960000   54.165000
# 50%     8.000000   89.940000   93.100000   69.380000   87.960000   66.670000
# 75%     8.000000   95.000000  100.550000   82.810000   98.425000   83.610000
# max     8.000000  100.830000  112.580000  110.000000  108.890000  108.890000

# %%
viz_data = data;

# %%
sns.boxenplot(data=viz_data['Prefix'],orient='v')
# Out:
# <Axes: >

# %%
sns.boxenplot(data=viz_data['Assignment'],orient='v')
# Out:
# <Axes: >

# %%
sns.pairplot(viz_data)

# %%
viz_data.corr()
sns.heatmap(viz_data.corr())
# Out:
# <Axes: >
